# %% [markdown]
# # Chi-Square Test for Independence
# Association between Device Type and Customer Satisfaction

# %% [markdown]
# ### Step 1: Import Libraries

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency, chi2

# %% [markdown]
# ### Step 2: Create the Contingency Table

# %%
data = np.array([
    [50, 70],   # Very Satisfied
    [80, 100],  # Satisfied
    [60, 90],   # Neutral
    [30, 50],   # Unsatisfied
    [20, 50]    # Very Unsatisfied
])

df = pd.DataFrame(
    data,
    columns=['Smart Thermostat', 'Smart Light'],
    index=['Very Satisfied', 'Satisfied', 'Neutral', 'Unsatisfied', 'Very Unsatisfied']
)

print('=== Contingency Table ===')
display(df)
# Out:
# === Contingency Table ===
#                   Smart Thermostat  Smart Light
# Very Satisfied                  50           70
# Satisfied                       80          100
# Neutral                         60           90
# Unsatisfied                     30           50
# Very Unsatisfied                20           50

# %% [markdown]
# ### Step 3: State the Hypotheses

# %%
print('Null Hypothesis (H0): There is no association between device type and customer satisfaction.')
print('Alternative Hypothesis (H1): There is a significant association between device type and customer satisfaction.')
# Out:
# Null Hypothesis (H0): There is no association between device type and customer satisfaction.
# Alternative Hypothesis (H1): There is a significant association between device type and customer satisfaction.

# %% [markdown]
# ### Step 4: Compute the Chi-Square Statistic

# %%
chi2_stat, p_value, dof, expected = chi2_contingency(data)
print(f'Chi-Square Statistic = {chi2_stat:.4f}')
print(f'Degrees of Freedom = {dof}')
print(f'P-value = {p_value:.4f}')
# Out:
# Chi-Square Statistic = 5.6382
# Degrees of Freedom = 4
# P-value = 0.2278

# %% [markdown]
# ### Step 5: Show Expected Frequencies

# %%
expected_df = pd.DataFrame(
    expected,
    columns=['Smart Thermostat', 'Smart Light'],
    index=['Very Satisfied', 'Satisfied', 'Neutral', 'Unsatisfied', 'Very Unsatisfied']
)
print('Expected Frequencies (if H0 is true):')
display(expected_df)
# Out:
# Expected Frequencies (if H0 is true):
#                   Smart Thermostat  Smart Light
# Very Satisfied                48.0         72.0
# Satisfied                     72.0        108.0
# Neutral                       60.0         90.0
# Unsatisfied                   32.0         48.0
# Very Unsatisfied              28.0         42.0

# %% [markdown]
# ### Step 6: Determine the Critical Value and Make a Decision

# %%
alpha = 0.05
critical_value = chi2.ppf(1 - alpha, dof)
print(f'Critical Value (α = {alpha}) = {critical_value:.4f}\n')
if chi2_stat > critical_value:
    print(f'Since Chi-Square statistic ({chi2_stat:.4f}) > Critical value ({critical_value:.4f}), we REJECT the null hypothesis.')
    print('Conclusion: There is a significant association between device type and customer satisfaction.')
else:
    print(f'Since Chi-Square statistic ({chi2_stat:.4f}) <= Critical value ({critical_value:.4f}), we FAIL TO REJECT the null hypothesis.')
    print('Conclusion: There is no significant association between device type and customer satisfaction.')
# Out:
# Critical Value (α = 0.05) = 9.4877
#
# Since Chi-Square statistic (5.6382) <= Critical value (9.4877), we FAIL TO REJECT the null hypothesis.
# Conclusion: There is no significant association between device type and customer satisfaction.
