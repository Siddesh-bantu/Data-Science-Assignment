# %%
# imported Required Libraries
import pandas as pd #used for data Manipulation
import numpy as np #used for numeric calculations
import seaborn as sns #used for Visualization
import matplotlib.pyplot as plt #Also used for the visualization

# %%
# imported warnings to avoid any warning
import warnings
warnings.filterwarnings('ignore')

# %%
# loaded the dataset in dataframe named df
df=pd.read_csv("Cardiotocographic.csv")

# %%
# dataframe df is viewed
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Checked for the no. of rows and no. of columns
df.shape
# Out:
# (2126, 14)

# %%
# Checked for top 10 records
df.head(10)
# Out:
#            LB        AC   FM        UC        DL   DS        DP  ASTV  MSTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  73.0   0.5
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.000000  17.0   2.1
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.000000  16.0   2.1
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.000000  16.0   2.4
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.000000  16.0   2.4
# 5  134.000000  0.001116  0.0  0.010493  0.009444  0.0  0.002099  26.0   5.9
# 6  134.000000  0.001403  0.0  0.012623  0.008415  0.0  0.002805  29.0   6.3
# 7  122.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  83.0   0.5
# 8  122.000000  0.038567  0.0  0.001517  0.000000  0.0  0.000000  84.0   0.5
# 9  122.000000  0.000000  0.0  0.002967  0.000000  0.0  0.000000  86.0   0.3
#
#    ALTV  MLTV       Width  Tendency       NSP
# 0  43.0   2.4   64.000000  0.999926  2.000000
# ...

# %%
# Ckecked for bottom 10 records
df.tail(10)
# Out:
#          LB        AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# 2116  140.0  0.003968  0.000000  0.003968  0.000000  0.0  0.0  80.0   0.2
# 2117  140.0  0.000000  0.000000  0.007812  0.000000  0.0  0.0  79.0   0.3
# 2118  140.0  0.000000  0.000000  0.006470  0.000898  0.0  0.0  79.0   0.5
# 2119  140.0  0.000000  0.000000  0.006764  0.001127  0.0  0.0  79.0   0.6
# 2120  140.0  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0   0.7
# 2121  140.0  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2116  36.000000   2.2   18.0  0.000000  1.000000
# 2117  20.000000   8.5   26.0  1.002932  1.000000
# ...

# %%
# using the df.info( ) we get the information about any missing values, datatype of the columns, no. of rows and columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
# using df.describe() we get to know the statistical distribution of the data like mean median, min, max, std, quantile...,etc
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
# using this we get to know the is there any null values in the dataframe, it gives output in the boolean format
df.isna()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
# We get the count of null values present in the each column of the dataframe
df.isna().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# df['LB'].value_counts().head(50)

# %%
# df['LB'].unique().sum()

# %%
# df['AC'].value_counts()

# %%
# df['FM'].value_counts()

# %%
# df['UC'].value_counts()

# %%
# df['DL'].value_counts()

# %%
# df['DS'].value_counts()

# %%
# df['DP'].value_counts()

# %%
# df['ASTV'].value_counts()

# %%
# df['MSTV'].value_counts()

# %%
# df['ALTV'].value_counts()

# %%
# df['MLTV'].value_counts()

# %%
# df['Width'].value_counts()

# %%
# df['Tendency'].value_counts()

# %%
# df['NSP'].value_counts()

# %%
# this returns the datatype of each column present in the dataframe. using this we can check for is there any mishandling or incorrect data is present in the column
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# here we've checked for the top 60 records of the 'LB' Column
df['LB'].head(60)
# Out:
# 0     120.000000
# 1     132.000000
# 2     133.000000
# 3     134.000000
# 4     131.948232
# 5     134.000000
# 6     134.000000
# 7     122.000000
# 8     122.000000
# 9     122.000000
# 10    151.000000
# 11    150.000000
# 12    131.000000
# 13    131.000000
# 14    130.000000
# 15    130.000000
# 16    130.000000
# 17    131.000000
# 18    130.000000
# 19    130.000000
# 20    129.000000
# 21    128.000000
# 22    128.000000
# 23    128.000000
# 24    128.000000
# 25    124.000000
# 26    124.000000
# 27    124.000000
# 28    132.000000
# 29    132.000000
# 30    132.000000
# 31    132.000000
# 32    132.000000
# 33    120.000000
# 34    120.000000
# 35    120.000000
# 36    115.000000
# 37    114.000000
# 38    115.000000
# 39    115.000000
# 40    114.000000
# 41    114.000000
# 42    116.000000
# 43    116.000000
# 44    122.000000
# 45    122.000000
# 46    122.000000
# 47    122.000000
# 48    122.000000
# 49    158.000000
# 50           NaN
# 51    156.000000
# ...

# %%
# Here we've printed the count of the null values present in the column 'LB' of the dataframe df. we got the 21 null values
print(df["LB"].isnull().sum())
# Out:
# 21

# %%
# here we've checked for the bottom 60 records of the 'LB' column. I found this function is able to show maximum 60 records only.
df['LB'].tail(60)
# Out:
# 2066    130.0
# 2067    130.0
# 2068    130.0
# 2069    130.0
# 2070    130.0
# 2071    130.0
# 2072    130.0
# 2073    130.0
# 2074    130.0
# 2075    130.0
# 2076    130.0
# 2077    130.0
# 2078    130.0
# 2079    130.0
# 2080    130.0
# 2081    130.0
# 2082    130.0
# 2083    130.0
# 2084    128.0
# 2085    128.0
# 2086    133.0
# 2087    133.0
# 2088    133.0
# 2089    133.0
# 2090    133.0
# 2091    133.0
# 2092    133.0
# 2093    133.0
# 2094    133.0
# 2095    133.0
# 2096    133.0
# 2097    133.0
# 2098    133.0
# 2099    133.0
# 2100    133.0
# 2101    133.0
# 2102    133.0
# 2103    133.0
# 2104    136.0
# 2105    136.0
# 2106    136.0
# 2107    136.0
# 2108    136.0
# 2109    136.0
# 2110    136.0
# 2111    136.0
# 2112    136.0
# 2113    136.0
# 2114    137.0
# 2115    140.0
# 2116    140.0
# 2117    140.0
# 2118    140.0
# 2119    140.0
# 2120    140.0
# 2121    140.0
# 2122    140.0
# 2123    140.0
# 2124    140.0
# 2125    142.0
# Name: LB, dtype: float64

# %%
# here I've visualized the histogram of 'LB' Column. plt.tight_layout() is used to adjust graph properly in the cell and to avoid overlapping of the bins.
# by visualizing i got the idea about there is outlier present in the "LB" column but i will confirm about an outliers using boxplot.
df['LB'].hist()
plt.tight_layout()

# %%
# here i've visualized the boxplot of the 'LB' column to confirm the presence of an outliers, We can see the outliers are present in the both sides at above the upper extreme
# and below the lower extreme.
sns.boxplot(x='LB',data=df)
# Out:
# <Axes: xlabel='LB'>

# %%
# Here i've visualized the Histogram and Boxplot Simultaneously in the one output cell using subplot function. This subplot function takes 3 arguments subplot(x,y,position)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.hist(df["LB"])
plt.subplot(1,2,2)
sns.boxplot(x=df["LB"])
# plt.tight_layout()
plt.show()

# %%
# here i've visualized the histogram and boxplot of the 'LB' column combinely
sns.histplot(df["LB"], bins=20, kde=True)#kde=Kernel Density Estimation
plt.show()
plt.title("Histogram")

sns.boxplot(x=df["LB"])
plt.show()

# %%
# calculated the mean of the 'LB' column using mean function simply
df['LB'].mean()
# Out:
# np.float64(133.3435983550352)

# %%
# by ckecking the isna() or isnull() i get to know that in the 'LB' column there is 21 null values , we cannot proceed the model with null values we have to impute the null
# values with some parameter so i've replaced all the null values present in the 'LB' column with its mean.

df['LB']=df['LB'].fillna(df['LB'].mean())

# %%
# here i've visualized histogram and boxplot of the 'LB' column with subplot function selected parameted edgecolor='black' to clearly see the bins.
plt.figure(figsize=(10,5))

# Histogram
plt.subplot(1,2,1)
plt.hist(df["LB"], bins=20, edgecolor="black")
plt.title("Histogram")

# Boxplot
plt.subplot(1,2,2)
plt.boxplot([df["LB"]])
plt.title("Boxplot")

plt.tight_layout()
plt.show()

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
# checked for the count of null values in the column 'AC' . here i see the 20 null values are present.
df['AC'].isna().sum()
# Out:
# np.int64(20)

# %%
# Here i've calculated the mean of the 'AC' column.
df['AC'].mean()
# Out:
# np.float64(0.0032189782438000465)

# %%
df['AC']=df['AC'].fillna(df['AC'].mean())

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
df['AC'].isna().sum()
# Out:
# np.int64(0)

# %%
df['DS'].isnull().sum()
# Out:
# np.int64(21)

# %%
df['DS'].mean()
# Out:
# np.float64(2.5089835057102827e-06)

# %%
df['DS']=df["DS"].fillna(df['DS'].mean())

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
df['DS'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['DP'].isna().sum()
# Out:
# np.int64(21)

# %%
df['DP'].mean()
# Out:
# np.float64(0.00017515121174634704)

# %%
df['DP']=df['DP'].fillna(df['DP'].mean())

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
df['DP'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df['MLTV'].isna().sum()
# Out:
# np.int64(21)

# %%
df['MLTV'].mean()
# Out:
# np.float64(8.28488742706321)

# %%
df['MLTV']=df['MLTV'].fillna(df['MLTV'].mean())

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
df['Width'].isna().sum()
# Out:
# np.int64(21)

# %%
df['Width'].mean()
# Out:
# np.float64(70.42926049411918)

# %%
# df['Width'].median()

# %%
df['Width']=df['Width'].fillna(df['Width'].mean())

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
df['Width'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Tendency'].isna().sum()
# Out:
# np.int64(21)

# %%
df['Tendency'].mean()
# Out:
# np.float64(0.3163714038702473)

# %%
df['Tendency']=df['Tendency'].fillna(df['Tendency'].mean())

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
df['Tendency'].isna().sum()
# Out:
# np.int64(0)

# %%
df['NSP'].isna().sum()
# Out:
# np.int64(21)

# %%
df['NSP'].mean()
# Out:
# np.float64(1.304507175110962)

# %%
df['NSP']=df['NSP'].fillna(df['NSP'].mean())

# %%
df.head(60)
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0   120.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   132.000000  0.006380  0.000000  0.006380  0.003190  0.000000  0.000000
# 2   133.000000  0.003322  0.000000  0.008306  0.003322  0.000000  0.000000
# 3   134.000000  0.002561  0.000000  0.007742  0.002561  0.000000  0.000000
# 4   131.948232  0.006515  0.000000  0.008143  0.000000  0.000000  0.000000
# 5   134.000000  0.001116  0.000000  0.010493  0.009444  0.000000  0.002099
# 6   134.000000  0.001403  0.000000  0.012623  0.008415  0.000000  0.002805
# 7   122.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 9   122.000000  0.000000  0.000000  0.002967  0.000000  0.000000  0.000000
# 10  151.000000  0.000000  0.000000  0.000834  0.000834  0.000000  0.000000
# ...

# %%
df.isna().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
sns.boxplot(x='ASTV',data=df)
# Out:
# <Axes: xlabel='ASTV'>

# %%
def Outlier_Detection(col_name,data):
  q1=data[col_name].quantile(0.25)
  q3=data[col_name].quantile(0.75)
  iqr=q3-q1

  upper_E=q3+(1.5*iqr)
  lower_E=q1-(1.5*iqr)
  return upper_E,lower_E

# %%
Outlier_Detection('LB',df)
# Out:
# (np.float64(161.0), np.float64(105.0))

# %%
Outlier_Detection('AC',df)
# Out:
# (np.float64(0.01401531875), np.float64(-0.00840919125))

# %%
Outlier_Detection('FM',df)
# Out:
# (np.float64(0.006416428125), np.float64(-0.003849856875))

# %%
Outlier_Detection('UC',df)
# Out:
# (np.float64(0.013563983874999998), np.float64(-0.005177445124999999))

# %%
Outlier_Detection('DL',df)
# Out:
# (np.float64(0.008223685), np.float64(-0.004934211))

# %%
Outlier_Detection('DS',df)
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
Outlier_Detection('DP',df)
# Out:
# (np.float64(0.0), np.float64(0.0))

# %%
Outlier_Detection('ASTV',df)
# Out:
# (np.float64(104.5), np.float64(-11.5))

# %%
Outlier_Detection('MSTV',df)
# Out:
# (np.float64(3.2), np.float64(-0.8))

# %%
Outlier_Detection('ALTV',df)
# Out:
# (np.float64(27.5), np.float64(-16.5))

# %%
Outlier_Detection('MLTV',df)
# Out:
# (np.float64(20.1), np.float64(-4.700000000000001))

# %%
Outlier_Detection('Width',df)
# Out:
# (np.float64(194.5), np.float64(-57.5))

# %%
Outlier_Detection('Tendency',df)
# Out:
# (np.float64(2.5), np.float64(-1.5))

# %%
Outlier_Detection('NSP',df)
# Out:
# (np.float64(1.0), np.float64(1.0))

# %%
df.loc[df['LB']>161.0,"LB"]=161.0

# %%
df['LB'].tail(60)
# Out:
# 2066    130.0
# 2067    130.0
# 2068    130.0
# 2069    130.0
# 2070    130.0
# 2071    130.0
# 2072    130.0
# 2073    130.0
# 2074    130.0
# 2075    130.0
# 2076    130.0
# 2077    130.0
# 2078    130.0
# 2079    130.0
# 2080    130.0
# 2081    130.0
# 2082    130.0
# 2083    130.0
# 2084    128.0
# 2085    128.0
# 2086    133.0
# 2087    133.0
# 2088    133.0
# 2089    133.0
# 2090    133.0
# 2091    133.0
# 2092    133.0
# 2093    133.0
# 2094    133.0
# 2095    133.0
# 2096    133.0
# 2097    133.0
# 2098    133.0
# 2099    133.0
# 2100    133.0
# 2101    133.0
# 2102    133.0
# 2103    133.0
# 2104    136.0
# 2105    136.0
# 2106    136.0
# 2107    136.0
# 2108    136.0
# 2109    136.0
# 2110    136.0
# 2111    136.0
# 2112    136.0
# 2113    136.0
# 2114    137.0
# 2115    140.0
# 2116    140.0
# 2117    140.0
# 2118    140.0
# 2119    140.0
# 2120    140.0
# 2121    140.0
# 2122    140.0
# 2123    140.0
# 2124    140.0
# 2125    142.0
# Name: LB, dtype: float64

# %%
df.loc[df["LB"]<105.0,'LB']=105.0

# %%
# # for col in df:
# def Outlier_Detection(data):
#   for col in data.columns:
#     q1=data[col].quantile(0.25)
#     q3=data[col].quantile(0.75)
#     iqr=q3-q1

#     upper_E=q3+(1.5*iqr)
#     lower_E=q1-(1.5*iqr)
#     # return upper_E,lower_E
#     data[col]=data.loc[data[col]<lower_E,col]=lower_E
#     data[col]=data.loc[data[col]>upper_E,col]=upper_E
#     # return upper_E,lower_E, LE_Capping,UE_Capping
#     return data

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# def cap_outliers_and_plot(data):
#     # Step 1: Capping for each column
#     for col in data.columns:
#         q1 = data[col].quantile(0.25)
#         q3 = data[col].quantile(0.75)
#         iqr = q3 - q1
#         upper_E = q3 + (1.5 * iqr)
#         lower_E = q1 - (1.5 * iqr)

#         # Apply capping
#         data[col] = data[col].clip(lower=lower_E, upper=upper_E)

#     # Step 2: Boxplot without showing outliers
#     plt.figure(figsize=(12,6))
#     sns.boxplot(data=data, showfliers=False)  # 🚀 this hides all outlier dots
#     plt.title("Boxplot after Outlier Capping (No Dots)")
#     plt.show()

#     return data

# %%
Outlier_Detection(df)
# Out:
#          LB        AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# 0     161.0  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 1     161.0  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 2     161.0  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 3     161.0  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 4     161.0  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...     ...       ...       ...       ...       ...  ...  ...   ...   ...
# 2121  161.0  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 2122  161.0  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 2123  161.0  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 2124  161.0  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 2125  161.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
for col in df.columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    upper_E = q3 + (1.5 * iqr)
    lower_E = q1 - (1.5 * iqr)

    # 👉 Actual capping
    df[col] = df[col].clip(lower=lower_E, upper=upper_E)

    print(col, "Min:", df[col].min(), "Max:", df[col].max(),
          "Expected range:", (lower_E, upper_E))
# Out:
# LB Min: 161.0 Max: 161.0 Expected range: (np.float64(161.0), np.float64(161.0))
# AC Min: -0.00840919125 Max: 0.01401531875 Expected range: (np.float64(-0.00840919125), np.float64(0.01401531875))
# FM Min: -0.003849856875 Max: 0.006416428125 Expected range: (np.float64(-0.003849856875), np.float64(0.006416428125))
# UC Min: -0.005177445124999999 Max: 0.013563983874999998 Expected range: (np.float64(-0.005177445124999999), np.float64(0.013563983874999998))
# DL Min: -0.004934211 Max: 0.008223685 Expected range: (np.float64(-0.004934211), np.float64(0.008223685))
# DS Min: 0.0 Max: 0.0 Expected range: (np.float64(0.0), np.float64(0.0))
# DP Min: 0.0 Max: 0.0 Expected range: (np.float64(0.0), np.float64(0.0))
# ASTV Min: -11.5 Max: 104.5 Expected range: (np.float64(-11.5), np.float64(104.5))
# MSTV Min: -0.8 Max: 3.2 Expected range: (np.float64(-0.8), np.float64(3.2))
# ALTV Min: -16.5 Max: 27.5 Expected range: (np.float64(-16.5), np.float64(27.5))
# ...

# %%
sns.boxplot(df)
plt.tight_layout()

# %%
sns.boxplot(data=df,x="LB")
# Out:
# <Axes: xlabel='LB'>

# %%
sns.boxplot(data=df,x='ASTV')
# Out:
# <Axes: xlabel='ASTV'>

# %%
corr = df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this EDA assignment i have loaded Cardiotocographic.csv dataset it consists of 2126 rows and 14 columns in which all the columns are continious numeric, some columns having null values to treat the missing values i used fillna() function. to fillna() function ive passed the mean/median of the particular column so missing values are treated well.
# i've aslo visualized boxplot of columns which gives the information about an outliers present in the column also plotted the histogram.
# To treat the outliers i used one user defined function which completely
# replaces the outliers with its corresponding extreme value, so the outlier treatment is done.
# Also visualized the heatmap which shows the correlation among the columns.
